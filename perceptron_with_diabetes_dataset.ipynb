# %% [markdown]
# <a href="https://colab.research.google.com/github/toriqultonu/Learning_PyTorch/blob/main/perceptron_with_diabetes_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("diabetes.csv")
features = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
target = ['Outcome']
print(data.shape)
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8dc04b5d4d6f> in <cell line: 1>()
# ----> 1 data = pd.read_csv("diabetes.csv")
#       2 features = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
#       3 target = ['Outcome']
#       4 print(data.shape)
#
# NameError: name 'pd' is not defined

# %%
df = data.sort_values("Outcome")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 383            1       90             62             18       59  25.1
# 465            0      124             56             13      105  21.8
# 466            0       74             52             10       36  27.8
# 467            0       97             64             36      100  36.8
# 469            6      154             78             41      140  46.1
# ..           ...      ...            ...            ...      ...   ...
# 193           11      135              0              0        0  52.3
# 485            0      135             68             42      250  42.3
# 484            0      145              0              0        0  44.2
# 186            8      181             68             36      495  30.1
# 0              6      148             72             35        0  33.6
#
#      DiabetesPedigreeFunction  Age  Outcome
# 383                     1.268   25        0
# ...

# %%
for column in df:
    sorted_col = df.sort_values(column)
    x_max = sorted_col[column].iloc[-1]
    x_min = sorted_col[column].iloc[0]
    range_x = x_max - x_min

    for i in range(df.shape[0]):
        df.loc[i, column] = (df[column][i] - x_min) / range_x

df.head()
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 383     0.058824  0.452261       0.508197       0.181818  0.069740  0.374069
# 465     0.000000  0.623116       0.459016       0.131313  0.124113  0.324888
# 466     0.000000  0.371859       0.426230       0.101010  0.042553  0.414307
# 467     0.000000  0.487437       0.524590       0.363636  0.118203  0.548435
# 469     0.352941  0.773869       0.639344       0.414141  0.165485  0.687034
#
#      DiabetesPedigreeFunction       Age  Outcome
# 383                  0.508113  0.066667        0
# 465                  0.159693  0.000000        0
# 466                  0.081554  0.016667        0
# 467                  0.222886  0.066667        0
# 469                  0.210504  0.100000        0

# %%
training = df.loc[:(768 * 80 // 100)]
test = df.loc[(768 * 80 // 100 + 1):]

x_training, y_training = training[features].values, training[target].values
x_test, y_test = test[features].values, test[target].values
print(x_training.shape, y_training.shape)
print(x_test.shape, y_test.shape)
# Out:
# (540, 8) (540, 1)
# (463, 8) (463, 1)

# %%
# Make a prediction with weights
def predict(row, weights):
    activation = weights[0]
    for i in range(len(row)-1):
        activation += weights[i + 1] * row[i]
    return 1.0 if activation > 0.0 else 0.0

 # Estimate Perceptron weights using stochastic gradient descent
def train_weights(train, l_rate, n_epoch):
    weights = [0.0 for i in range(len(train[0]))]    # Weights[0] is bias
    for epoch in range(n_epoch):
        sum_error = 0.0
        for row in train:
            prediction = predict(row, weights)
            error = row[-1] - prediction
            sum_error += error**2
            weights[0] = weights[0] + l_rate * error
            for i in range(len(row)-1):
                weights[i + 1] = weights[i + 1] + l_rate * error * row[i]

    return weights

 # Perceptron Algorithm With Stochastic Gradient Descent
def perceptron(train, test, l_rate, n_epoch):
    predictions = list()
    weights = train_weights(train, l_rate, n_epoch)
    for row in test:
        prediction = predict(row, weights)
        predictions.append(prediction)
    return predictions

l_rate = 0.1
n_epoch = 50
predicted = perceptron(training.values, test.values, l_rate, n_epoch)

for i in range(80):
    print(f'Predicted: {predicted[i]}, Actual:{y_test[i][0]}')
# Out:
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 0.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 0.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 0.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# Predicted: 1.0, Actual:0
# ...
